# %%
import synthsolar
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

Ktm = [0.49, 0.48, 0.50, 0.51, 0.51, 0.54, 0.54, 0.57, 0.56, 0.54, 0.51, 0.51]
lat = 34.8
G0 = synthsolar.Aguiar_hourly_G0(Ktm, lat)

dates = pd.date_range('1/1/2017', periods = 365*24, freq = 'H')
ts = pd.Series(G0, index = dates)

ts.plot()

# %%
ts[:24].plot()
